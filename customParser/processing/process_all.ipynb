# %%
import pandas as pd
import os

print("Reading log_templates.csv and log_structured.csv\n")

# Read log_templates.csv and log_structured.csv
templates_df = pd.read_csv('label_result/log_templates.csv')
structured_df = pd.read_csv('label_result/log_structured.csv')

# Define mapping of Label values to TYPE
label_to_type = {1: 'POSITIVE', 2: 'NEUTRAL', 3: 'NEGATIVE'}

# Check if unlabelled file exists, delete it if it does
unlabelled_log = 'unlabelled/log'
if os.path.exists(unlabelled_log):
    os.remove(unlabelled_log)

template_cnt = 0
structured_data_cnt = 0

# Initialize empty lists to store the data
template_data = []
structured_data = []

# Iterate over each row in templates_df
for index, row in templates_df.iterrows():
    print(f"Labelling template >> {row['EventTemplate']}")
    # Extract corresponding records from structured_df
    corresponding_records = structured_df[structured_df['EventId'] == row['EventId']].copy()

    # Add TYPE column and map Label values
    corresponding_records['Label'] = label_to_type.get(row['Label'], 'NEUTRAL')

    # Append the template data
    template_data.append({'Label': label_to_type.get(row['Label'], 'NEUTRAL'), 'Template': row['EventTemplate']})

    # Append the structured data
    for _, record in corresponding_records.iterrows():
        structured_data.append(record.tolist())
        structured_data_cnt += 1

    template_cnt += 1


print("Total templates", template_cnt)
print("Processed records", structured_data_cnt)
# Out:
# Reading log_templates.csv and log_structured.csv
#
# Labelling template >> <*> : default SNMP TRAP_SENT 0 0 : lldpRemTablesChange <*> = <*> <*> = <*> <*> = <*> nsPartitionName = default)
# Labelling template >> 01010281:4: Inet port exhaustion threshold reached on <*> to <*> (proto <*>
# Labelling template >> EVENT STATECHANGE <*> 0 : Device "self node <*>" - State "SYNC Failure - Save remote config failed"
# Labelling template >> <*> : default EVENT DEVICEDOWN <*> <*> : Device <*> - State <*>
# Labelling template >> <*> : default EVENT DEVICEDOWN <*> <*> : Device <*>
# Labelling template >> <*> : default EVENT DEVICEDOWN <*> <*> : Device <*> -
# Labelling template >> 01010201:2: Inet port exhaustion on <*> to <*> (proto <*>
# Labelling template >> <*> Per-invocation log rate exceeded; throttling.
# Labelling template >> 0-PPE-0 : default EVENT STATECHANGE <*> 0 : Device <*> node <*>" - State <*>
# Labelling template >> <*> : default EVENT DEVICEUP <*> <*> : Device <*>
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : <*> <*> = <*> <*> = <*> nsPartitionName = default)
# Labelling template >> <*> : default EVENT MONITORUP <*> <*> : Monitor <*>
# Labelling template >> <*> AUDIT - user admin - RAW: <*> user=admin(admin) partition=[All] level=Administrator <*> <*> attempts=1 <*> <*> <*> <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> <*> : default SNMP TRAP_SENT <*> 0 : <*> <*> = <*> nsPartitionName = default)
# Labelling template >> 01010045:5: Bandwidth utilization is <*> Mbps, exceeded 75% of Licensed <*> Mbps
# Labelling template >> user=admin(admin) partition=[All] level=Administrator tty=(unknown) host=<*> attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> <*> : default EVENT DEVICEUP <*> <*> : Device <*> - State UP
# Labelling template >> 01490506:5: <*> Received User-Agent header: <*>
# Labelling template >> <*> : default EVENT DEVICEUP <*> <*> : Device <*> -
# Labelling template >> 019a0018:3: 00000000: <*> Received error from tmm filter (7)
# Labelling template >> user=admin(admin) partition=[All] level=Administrator tty=(unknown) host=(unknown) attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> <*> Resuming log processing at this invocation; held <*> messages.
# Labelling template >> 01200015:4: Warning, ICMP error limit reached.
# Labelling template >> <*> : default EVENT MONITORDOWN <*> <*> : Monitor <*>
# Labelling template >> 019a0020:3: <*> Ping Access encountered error: <*> Function: <*> Line: <*>
# Labelling template >> ltm driver: Idle enforcer exiting - tid: <*> cpu: <*>
# Labelling template >> XMT: Solicit on mgmt, interval <*>
# Labelling template >> <*> : default SSLVPN Message <*> 0 : "CVPN_V2_DHT : ns_cvpn_v2_cookie_jar_dht_entry_cleanup"
# Labelling template >> Rule /Common/dns_resp_time <DNS_RESPONSE>: Pool_Member: <*> DNS_NAME: <*> DNS_time: <*> ms
# Labelling template >> 013a0006:5: mcpd tells us that config is being saved; incrementing this blade's revision and saving cluster config
# Labelling template >> 01070417:6: AUDIT - user esm-mon - RAW: httpd(pam_audit): User=esm-mon tty=(unknown) host=<*> failed to login after 1 attempts <*> <*> <*> <*> 2024" <*> <*> <*> <*> 2024").
# Labelling template >> User=esm-mon tty=(unknown) host=<*> failed to login after 1 attempts (start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024").
# Labelling template >> [auth_pam:error] [pid <*> [client <*>] AUTHCACHE PAM: user 'esm-mon' (fallback: false) - not authenticated: User not known to the underlying authentication module
# Labelling template >> 01220009:6: Pending rule /Common/dns_resp_time <DNS_RESPONSE> aborted for <*> -> <*>
# Labelling template >> <*> : default SSLVPN Message <*> 0 : "ns_rba_krpc_user_auth: Encrypted Password"
# Labelling template >> 0-PPE-1 : default SNMP TRAP_SENT <*> 0 : haNoHeartbeats (haNicsMonitorFailed = "0/1 LA/1", haLastNicMonitorFailed = <*> nsPartitionName = default)
# Labelling template >> <*> : default SNMP TRAP_SENT <*> 0 : haNoHeartbeats (haNicsMonitorFailed = <*> haLastNicMonitorFailed = <*> nsPartitionName = default)
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 pb_op_longer_hb for critical process <*> <*> <*> secs"
# Labelling template >> 014902b4:5: <*> SAML Agent: /Common/qwmgate_accesspolicy_act_saml_auth_ag, Matched IdP connector (/Common/PING-CERT) for SAML SP Initiated Auth (/Common/qwmgate.wal-mart.com) and landingURI <*>
# Labelling template >> <*> : default EVENT DEVICEUP <*> <*> : Device <*> - S
# Labelling template >> <*> <*> RestServer, INFO,onScheduleTask(3) for workerUri:tmapi_mapper took longer than 10 seconds
# Labelling template >> ltm driver: Idle enforcer starting - tid: <*> cpu: <*>
# Labelling template >> <*> : default EVENT MONITORDOWN <*> <*> : Monitor <*> - State <*>
# Labelling template >> 22007,22010, RestServer, INFO,ScheduledTasks running late
# Labelling template >> 019a0016:5: Main Flow aborted when resumed as TIMEOUT
# Labelling template >> <*> <*> RestServer, INFO,ScheduledTasks running late
# Labelling template >> 0-PPE-0 : default EVENT STATECHANGE <*> 0 : Device "self node <*>" - InitDueToRequestFrom HA peer node
# Labelling template >> Rule /Common/dns_resp_time <DNS_RESPONSE>: Client <*> Pool_Member: <*> DNS_NAME: <*> Answer: <*> DNS_time: <*> ms
# Labelling template >> <*> RestServer, INFO,onScheduleTask(3) for workerUri:tmapi_mapper took longer than 10 seconds
# Labelling template >> 01070417:6: AUDIT - user <*> - RAW: <*> <*> partition=[All] <*> <*> <*> attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> user=svc_f5_tcollector(svc_f5_tcollector) partition=[All] level=Auditor tty=(unknown) host=<*> attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> pam_unix(httpd:auth): authentication failure; logname= uid=48 euid=48 tty= ruser= rhost=<*>
# Labelling template >> pam_unix(httpd:auth): check pass; user unknown
# Labelling template >> pam_tally2(httpd:auth): pam_get_uid; no such user
# Labelling template >> <*> : default EVENT DEVICEDOWN <*> <*> : Device <*> - S
# Labelling template >> <*> RestServer, INFO,Connection idle too long <*>
# Labelling template >> 01490248:5: <*> Received client info - Hostname: Type: Mozilla Version: <*> Platform: <*> CPU: <*> UI Mode: Full Javascript Support: 1 ActiveX Support: 0 Plugin Support: <*>
# Labelling template >> 01490102:5: <*> Access policy result: LTM+APM_Mode
# Labelling template >> 01490005:5: <*> Following rule 'fallback' from item 'Logging' to ending 'Allow'
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c85fcf3d: Logging Agent
# Labelling template >> 01490265:5: <*> BIG-IP as SP (/Common/wmgate.wal-mart.com) have received SAML Assertion from IdP (/Common/PING_PROD) for subject type (urn:oasis:names:tc:SAML:1.1:nameid-format:unspecified) value <*>
# Labelling template >> 014902b4:5: <*> SAML Agent: /Common/wmgate_accesspolicy_act_saml_auth_ag, Matched IdP connector (/Common/PING_PROD) for SAML SP Initiated Auth (/Common/wmgate.wal-mart.com) and landingURI <*>
# Labelling template >> [auth_f5_auth_token:error] [pid <*> [client <*>] Got exception while handling EM auth token request: Invalid Token: Could not decrypt authentication token: Could not RSA decrypt authentication token.
# Labelling template >> 01070417:6: AUDIT - user <*> - RAW: <*> <*> tty=(unknown) host=<*> failed to login after 1 attempts (start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024").
# Labelling template >> <*> tty=(unknown) host=<*> failed to login after 1 attempts (start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024").
# Labelling template >> password check failed for user <*>
# Labelling template >> 01220001:3: TCL error: /Common/radius_mac_sticky_10hr <CLIENT_DATA> - attempt to use empty persistence key (line 25) invoked from within "persist uie $nas_ip $persist_ttl"
# Labelling template >> 0149020f:3: <*> SAML Agent: /Common/wmgate_accesspolicy_act_saml_auth_ag cannot find assertion information in SAML request
# Labelling template >> 0149020f:3: <*> SAML Agent: /Common/qwmgate_accesspolicy_act_saml_auth_ag cannot find assertion information in SAML request
# Labelling template >> (root) CMD (/usr/bin/lsusb -v -d 0451:3410 >/dev/null)
# Labelling template >> (root) CMD (/usr/bin/copy_rrd save)
# Labelling template >> (root) CMD (/usr/bin/updatecheck -a )
# Labelling template >> (root) CMD ((sleep 30; /root/trigger_wdr_cs.sh))
# Labelling template >> (root) CMD (/root/trigger_wdr_cs.sh)
# Labelling template >> <*> : default EVENT MONITORUP <*> <*> : Monitor <*> - State <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fffa0f2f: Logging Agent
# Labelling template >> Stopping user-199.slice.
# Labelling template >> Removed slice user-199.slice.
# Labelling template >> (syscheck) CMD (/usr/bin/system_check -q)
# Labelling template >> Starting user-199.slice.
# Labelling template >> Created slice user-199.slice.
# Labelling template >> 01010221:5: Pool <*> now has available members
# Labelling template >> <*> SNMP_TRAP: Virtual /Common/rad-cdc.mfa_1820 has become <*>
# Labelling template >> component = Policy Builder }
# Labelling template >> IPSEC Message <*> 0 : "exiting#012"
# Labelling template >> IPSEC Message <*> 0 : "failed creating /var/run/iked.pid#012"
# Labelling template >> IPSEC Message <*> 0 : "/var/run/iked.pid: write: No space left on device#012"
# Labelling template >> IPSEC Message <*> 0 : "starting iked for racoon2 20100526a#012"
# Labelling template >> 01010028:3: No members available for pool <*>
# Labelling template >> 011e0001:4: Limiting icmp unreach response from <*> to <*> packets/sec for traffic-group <*>
# Labelling template >> 01100045:1: /var/log disk usage exceeds 90%. Reduce log disk space now
# Labelling template >> user=svcnetops(svcnetops) partition=[All] level=Administrator tty=(unknown) host=<*> attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> Removed slice user-0.slice.
# Labelling template >> 01100048:0: Log disk usage still higher than 80% after logrotate and 24 times log deletion
# Labelling template >> Configuration reload request received, reloading configuration;
# Labelling template >> WARNING: Default value changed for the prefix() option of systemd-journal source in syslog-ng 3.8; old_value='', new_value='.journald.'
# Labelling template >> Stopping user-0.slice.
# Labelling template >> 01100043:5: logcheck Notice: Receive alert msg from diskmonitor 0
# Labelling template >> 011d0004:3: Disk partition /var/log has only <*> free
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b845b681: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f353f8c0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c64ec57a: Logging Agent
# Labelling template >> 01010029:5: Clock advanced by <*> ticks
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = successful, nsClientIPAddr = <*>, nsPartitionName = default)
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = successful, nsClientIPAddr = <*>, nsPartitionName = default)
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = successful, nsClientIPAddr = <*>, nsPartitionName = default)
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = successful, nsClientIPAddr = <*>, nsPartitionName = default)
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = failed, nsClientIPAddr = <*>, commandFailureReason = "ERROR: <*> <*> <*> nsPartitionName = default)
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> <*> <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = successful, nsClientIPAddr = <*>, nsPartitionName = default)
# Labelling template >> (root) CMD (/usr/lib64/sa/sa1 1 1)
# Labelling template >> (root) CMD (nice -n 19 ionice -c 3 <*>
# Labelling template >> Starting user-0.slice.
# Labelling template >> Created slice user-0.slice.
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:97af8459: Logging Agent
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : <*> (nsPartitionName = default)
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5df65ce3: Logging Agent
# Labelling template >> <*> : default EVENT MONITORUP <*> 0 : Monitor <*> -
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:85f8c071: Logging Agent
# Labelling template >> 01070417:5: AUDIT - user admin - RAW: httpd(mod_auth_pam): user=admin(admin) partition=[All] level=Administrator <*> host=<*> attempts=1 <*> <*> <*> <*> 2024".
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:61a7df60: Logging Agent
# Labelling template >> <*> : default EVENT MONITORUP <*> 0 : Monitor <*> - <*>
# Labelling template >> [auth_pam:error] [pid 12486] [client <*>] AUTHCACHE PAM: user 'svcnetops' (fallback: false) - not authenticated: User not known to the underlying authentication module, referer: https://lb-sdc-srv1-2.wal-mart.com/tmui/login.jsp
# Labelling template >> (root) CMD (/usr/bin/diskmonitor)
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:de6dcd2a: Logging Agent
# Labelling template >> 17446,17459, RestServer, INFO,ScheduledTasks running late
# Labelling template >> <*> : default EVENT MONITORDOWN <*> 0 : Monitor <*> - <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a76bcf90: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e46aa271: Logging Agent
# Labelling template >> <*> : default SNMP TRAP_SENT 0 0 : netScalerConfigChange (nsUserName = <*> configurationCmd = "unbind lb group <*> <*> authorizationStatus = authorized, commandExecutionStatus = failed, nsClientIPAddr = <*>, commandFailureReason = "ERROR: LB group does not exist", nsPartitionName = default)
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d8d08d74: Logging Agent
# Labelling template >> <*> : default EVENT MONITORDOWN <*> 0 : Monitor <*> -
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dcaecd7f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5c731faf: Logging Agent
# Labelling template >> user=svcnetops(svcnetops) partition=[All] level=Administrator tty=(unknown) host=(unknown) attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> 012a0005:5: -- SEL time synced to host time <*> <*> <*> <*> 2024
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:cc713200: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ece72bd8: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2c9e20ef: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d599e761: Logging Agent
# Labelling template >> 17444,17466, RestServer, INFO,ScheduledTasks running late
# Labelling template >> 16555,16567, RestServer, INFO,ScheduledTasks running late
# Labelling template >> 13596,13661, RestServer, INFO,ScheduledTasks running late
# Labelling template >> Audit daemon rotating log files
# Labelling template >> Cannot open localhost:25
# Labelling template >> Unable to connect to "localhost" port 25.
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ed64f1e6: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d99ce81c: Logging Agent
# Labelling template >> Connection closed by <*> port <*> [preauth]
# Labelling template >> 01020036:3: The requested pool member (/Common/j2ee-ifserverises_80_pool /Common/_auto_<*> 80) was not found.
# Labelling template >> src=<*>, user=
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:6ce250cf: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:134a82df: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d0536d55: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d1d03e93: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:220b68bc: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d32dde01: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1cde4fe4: Logging Agent
# Labelling template >> <*> <*> RestServer, INFO,Connection idle too long <*>
# Labelling template >> 01490517:5: <*> User-Agent header is absent or empty
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : vserverRhiStateChange (alarmVipRhiState = <*> alarmVipRhiInetAddressType = IPv4, alarmVipRhiInetAddress = <*>, nsPartitionName = default)
# Labelling template >> <*> : default EVENT VIPRHIUP <*> <*> : RHI state of VIP IPAddr_(<*>) - State UP
# Labelling template >> <*> : default ROUTING Message <*> <*> : "ROUTE (<*> <*> <*>) - <*>
# Labelling template >> 17442,17455, RestServer, INFO,ScheduledTasks running late
# Labelling template >> <*> : default EVENT VIPRHIDOWN <*> <*> : RHI state of VIP IPAddr_(<*>) - State DOWN
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d05a5361: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5ea80473: Logging Agent
# Labelling template >> <*> SNMP_TRAP: Virtual /Common/NHS_SCIGW_SCOT_NHS_UK_UKDCA_VIP has become <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7c8740dd: Logging Agent
# Labelling template >> <*> : default SNMP TRAP_SENT 0 <*> : netScalerConfigChange (nsUserName = <*> configurationCmd = <*> <*> <*> <*> authorizationStatus = authorized, commandExecutionStatus = failed, nsClientIPAddr = <*>, commandFailureReason = "ERROR: <*> <*> <*> nsPartitionName = default)
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1caf46f4: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2bbc73a6: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7a3b4524: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:271baa09: Logging Agent
# Labelling template >> <*> : default SSLVPN Message <*> 0 : "rba external auth request for <*> Auth : User <*> bitmask: <*> req_flags <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d19b6cdb: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:aab3b421: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:18d65580: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b9d30bbe: Logging Agent
# Labelling template >> 01490248:5: <*> Received client info - Hostname: Type: Safari Version: 1 Platform: <*> CPU: unknown UI Mode: Mobile Smart Phone Javascript Support: 1 ActiveX Support: 0 Plugin Support: 0
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:edb62025: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c28d5bad: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d98a77e2: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5a4349cf: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9004d9e2: Logging Agent
# Labelling template >> 011e0001:4: Limiting unreachable response from 251 to 250 packets/sec for traffic-group /Common/traffic-group-1
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8f60057e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7140e018: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:daaa6e4e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f4d9f6a8: Logging Agent
# Labelling template >> finished zrd_logrotate
# Labelling template >> starting zrd_logrotate
# Labelling template >> finished wr_urldbd_logrotate
# Labelling template >> starting wr_urldbd_logrotate
# Labelling template >> finished wa_logrotate
# Labelling template >> starting wa_logrotate
# Labelling template >> finished update_scanner_site_map.pl
# Labelling template >> starting update_scanner_site_map.pl
# Labelling template >> finished send_sync.pl
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ab47499a: Logging Agent
# Labelling template >> starting send_sync.pl
# Labelling template >> finished save_cores.pl
# Labelling template >> starting save_cores.pl
# Labelling template >> finished rand_seed_update
# Labelling template >> starting rand_seed_update
# Labelling template >> finished iprepd_logrotate
# Labelling template >> starting iprepd_logrotate
# Labelling template >> finished genkeys-1024
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:6571f3f8: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:29815da7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b2848940: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ea99c225: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dd891120: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:09764d80: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8311216c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d53bbe5e: Logging Agent
# Labelling template >> starting genkeys-1024
# Labelling template >> finished genkeys
# Labelling template >> starting genkeys
# Labelling template >> finished fpuserd_logrotate
# Labelling template >> starting fpuserd_logrotate
# Labelling template >> finished flowspecd_logrotate
# Labelling template >> starting flowspecd_logrotate
# Labelling template >> finished ecmd_logrotate
# Labelling template >> starting ecmd_logrotate
# Labelling template >> finished dwbld_logrotate
# Labelling template >> starting dwbld_logrotate
# Labelling template >> finished dosl7d_tcpdumps_cleaner
# Labelling template >> starting dosl7d_tcpdumps_cleaner
# Labelling template >> finished dosl7d_logrotate
# Labelling template >> starting dosl7d_logrotate
# Labelling template >> finished datasyncd_logrotate
# Labelling template >> starting datasyncd_logrotate
# Labelling template >> finished cbr_logrotate
# Labelling template >> starting cbr_logrotate
# Labelling template >> finished captured_logrotate
# Labelling template >> starting captured_logrotate
# Labelling template >> finished botd_logrotate
# Labelling template >> starting botd_logrotate
# Labelling template >> finished avr_run_scheduled_reports
# Labelling template >> starting avr_run_scheduled_reports
# Labelling template >> finished avr_logrotate
# Labelling template >> starting avr_logrotate
# Labelling template >> finished autodosd_logrotate
# Labelling template >> finished pwdcheck
# Labelling template >> starting pwdcheck
# Labelling template >> starting autodosd_logrotate
# Labelling template >> finished 0anacron
# Labelling template >> starting 0anacron
# Labelling template >> (root) CMD (run-parts /etc/cron.hourly)
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3364c5d9: Logging Agent
# Labelling template >> [auth_pam:error] [pid <*> [client <*>] AUTHCACHE PAM: user <*> (fallback: false) - not authenticated: Authentication failure
# Labelling template >> (root) CMD (/usr/bin/coreexpiration)
# Labelling template >> pam_unix(httpd:auth): authentication failure; logname= uid=48 euid=48 tty= ruser= rhost=<*> user=admin
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9482e2e8: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3b830e50: Logging Agent
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 There may be a delay while collecting core dump on nscfsyncd <*>
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 Sending SIGABRT to nscfsyncd <*> Missed (5) heartbeats"
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 There may be a delay restarting process while collecting core dump on nscfsyncd <*>
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 nscfsyncd <*> died due to receiving signal"
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 New pid <*> for (nscfsyncd) restarts (5)"
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 Restarting process nscfsyncd old pid <*> action (/netscaler/nscfsyncd nscfsyncd -P)"
# Labelling template >> 0-PPE-2 : default PITBOSS1 Message <*> 0 : <*> <*> <*> <*> 2024 process nscfsyncd <*> (/netscaler/nscfsyncd nscfsyncd -P) still running after death notification! Sending SIGKILL"
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5dad912e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:62d7df68: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dc01075b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:92c6ceeb: Logging Agent
# Labelling template >> 011e0001:4: Limiting open port RST response from <*> to <*> packets/sec for traffic-group /Common/traffic-group-1
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:44574156: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c171fe6c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:851f5400: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:db551708: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:15abfd07: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:149dfd7b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d8c7924f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c6b838dc: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0f332f02: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:adcdba0f: Logging Agent
# Labelling template >> audit_forwarder started.
# Labelling template >> <*> SNMP_TRAP: Virtual /Common/pfedprodext-cdc_443 has become <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:bcf74160: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1aa9339e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7d72cade: Logging Agent
# Labelling template >> 01020036:3: The requested node address (/Common/_auto_<*>) was not found.
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2bef1d76: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:42b44cde: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:cc6fd3de: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:127e189e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c05f2bb7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:cc2b0802: Logging Agent
# Labelling template >> <*> SNMP_TRAP: Virtual /Common/devcanp-tririga_443 has become <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b9578f0b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e1395803: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:19f3c7fb: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3ba8b21d: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f2959aa6: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8c48c22f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2ccc723a: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5a109f9b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b4a55192: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d16c26a9: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5907d734: Logging Agent
# Labelling template >> user=root(root) partition=[All] level=Administrator tty=ssh host=<*> attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:79ae3e19: Logging Agent
# Labelling template >> 01070417:6: AUDIT - user root - RAW: sshd(pam_audit): user=root(root) partition=[All] level=Administrator tty=ssh host=<*> attempts=1 <*> <*> <*> <*> 2024".
# Labelling template >> user=root(root) partition=[All] level=Administrator tty=ssh host=<*> attempts=1 <*> <*> <*> <*> 2024".
# Labelling template >> Accepted keyboard-interactive/pam for root from <*> port <*> ssh2
# Labelling template >> /usr/libexec/openssh/sftp-server
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:14d4b318: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2d784245: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1a6b1e1a: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a54599a0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:74b65c4a: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dc9a12b3: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:14d069d7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:34cabefa: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d8193cb7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f438c26f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:19705602: Logging Agent
# Labelling template >> 01490514:3: (null):Common:00000000: Access encountered error: <*> File: ../modules/hudfilter/access/access.c, Function: <*> Line: <*>
# Labelling template >> 01490547:4: Access Profile /Common/wmgate_accesspolicy: Per IP in-progress sessions limit <*> exceeded for <*>
# Labelling template >> 01490531:4: <*> Detected invalid host header <*> originating from IP <*>.
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:21ee612e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:078088c3: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:6368a0ec: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:34523455: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e1495ccb: Logging Agent
# Labelling template >> user=svclbadm(svclbadm) partition=[All] level=Administrator tty=ssh host=<*> attempts=1 start="Fri Mar 1 <*> 2024" end="Fri Mar 1 <*> 2024".
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8edb1010: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:94d9c738: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f73e3cd0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:4c142de8: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5b85fede: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:caf04bf0: Logging Agent
# Labelling template >> <*> SNMP_TRAP: Virtual /Common/rightfaxqa-edc_443 has become <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:68ec61cd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:04cb902d: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ba5643f9: Logging Agent
# Labelling template >> 01071681:5: SNMP_TRAP: Virtual <*> has become available
# Labelling template >> 01071682:5: SNMP_TRAP: Virtual <*> has become unavailable
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a129646e: Logging Agent
# Labelling template >> scp -f /var/local/ucs/l-cdc-tier1d-estore-01.net.walmart.com.ucs
# Labelling template >> 01420012:5: private key export: All keys are being exported by user "svclbadm" via UCS saving at file <*>
# Labelling template >> scp -f /var/local/ucs/l-cdc-tier1d-estore-02.net.walmart.com.ucs
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e21b78db: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-ndc-sap1-2.wal-mart.com.ucs
# Labelling template >> Skipping <*> iapp package that does not have iapp path: <*>
# Labelling template >> scp -f /var/local/ucs/lb-ndc-svc-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-sap1-1.wal-mart.com.ucs
# Labelling template >> ASM config saved
# Labelling template >> Failed to get getRPM build response within timeout for f5-telemetry
# Labelling template >> Failed task: <*> Failed to build RPM for f5-telemetry
# Labelling template >> scp -f /var/local/ucs/lb-ndc-srv2pci1-2.secure.wal-mart.com.ucs
# Labelling template >> user=svclbadm(svclbadm) partition=[All] level=Administrator tty=ssh host=<*> attempts=1 <*> <*> <*> <*> 2024".
# Labelling template >> Accepted keyboard-interactive/pam for svclbadm from <*> port <*> ssh2
# Labelling template >> pam_tacplus: pam_tacplus: user svclbadm successfully authenticated
# Labelling template >> 01070417:6: AUDIT - user svclbadm - RAW: sshd(pam_audit): user=svclbadm(svclbadm) partition=[All] level=Administrator tty=ssh host=<*> attempts=1 <*> <*> <*> <*> 2024".
# Labelling template >> scp -f /var/local/ucs/lb-ndc-srv2pci1-1.secure.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-svc-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-srv2-4.wal-mart.com.ucs
# Labelling template >> error: PAM: User not known to the underlying authentication module for <*> from <*>
# Labelling template >> pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=<*>
# Labelling template >> pam_unix(sshd:auth): check pass; user unknown
# Labelling template >> pam_tally2(sshd:auth): pam_get_uid; no such user
# Labelling template >> Exporting: f5-telemetry - /var/config/rest/iapps/f5-telemetry
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3b5cbe58: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-ndc-srv2-3.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-srv2-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-srv2-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum4-4.wal-mart.com.ucs
# Labelling template >> 011e0001:4: Limiting closed port RST response from <*> to <*> packets/sec for traffic-group /Common/traffic-group-1
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7660f04b: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum4-3.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum4-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum4-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum2-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum2-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum1-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-ossum1-1.wal-mart.com.ucs
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5ca09a43: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-ndc-dmz1svc1-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-os2381-2.wal-mart.com.ucs
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:322a7e17: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-ndc-dns-4.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-dmz1svc1-1.wal-mart.com.ucs
# Labelling template >> basicRestJavadQuery Error on request(400): POST /shared/iapp/build-package {"appName":"f5-telemetry"}
# Labelling template >> scp -f /var/local/ucs/lb-ndc-dns-3.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-dns-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-os2371-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-os2371-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-ndc-dns-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-svc-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-svc-1.wal-mart.com.ucs
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0a1562c2: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-edc-srv2pci1-2.secure.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-srv2-4.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-srv2pci1-1.secure.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-srv2-3.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-srv2-1.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-srv2-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-osfb1-2.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-ossum4-6.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-ossum4-5.wal-mart.com.ucs
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d61e1798: Logging Agent
# Labelling template >> scp -f /var/local/ucs/lb-edc-ossum4-3.wal-mart.com.ucs
# Labelling template >> scp -f /var/local/ucs/lb-edc-os2381-1.wal-mart.com.ucs
# Labelling template >> Killed process 17569 (icrd_child) total-vm:502264kB, anon-rss:186500kB, file-rss:17024kB, shmem-rss:8kB
# Labelling template >> Out of memory: Kill process 6444 (java) score 29 or sacrifice child
# Labelling template >> [20411] 0 20411 22114 6755 28 0 0 getdb
# Labelling template >> [20405] 0 20405 22612 2194 24 0 0 perl
# Labelling template >> [20402] 0 20402 28802 77 12 0 0 asm_logrotate
# Labelling template >> [20399] 0 20399 28802 231 12 0 0 rest_logintegri
# Labelling template >> [20395] 199 20395 12160 6168 19 0 0 system_check
# Labelling template >> <*> 0 <*> 42460 310 39 110 0 crond
# Labelling template >> [ 5123] 0 5123 4243 1608 12 0 0 python
# Labelling template >> [ 5044] 0 5044 29066 505 13 0 0 cs_save_pre_scr
# Labelling template >> [ <*> 0 <*> <*> <*> 53 0 0 tmsh
# Labelling template >> [ 4992] 0 4992 28802 259 13 0 0 bash
# Labelling template >> [ 4967] 0 4967 40750 1081 81 0 0 sshd
# Labelling template >> [ <*> 48 <*> 30616 <*> 36 <*> 0 httpd
# Labelling template >> [ 1708] 141501708 1708 10739 3883 22 2200 0 audit_forwarder
# Labelling template >> [20378] 48 20378 30617 1862 39 3927 0 httpd
# Labelling template >> [14309] 48 14309 30616 1397 36 4167 0 httpd
# Labelling template >> [32349] 0 32349 112254 33424 203 23780 0 icrd_child
# Labelling template >> [17569] 0 17569 125566 50883 234 19624 0 icrd_child
# Labelling template >> [13340] 0 13340 4589 819 13 1355 0 big3d
# Labelling template >> [13321] 0 13321 42190 3991 70 4175 0 iControlPortal.
# Labelling template >> [13320] 48 13320 1015 175 5 39 0 rtstats
# Labelling template >> [13319] 48 13319 1083 173 6 52 0 rrdstats
# Labelling template >> [13317] 48 13317 15987 3648 23 2356 0 mcpq
# Labelling template >> [13315] 48 13315 30344 116 30 4836 0 httpd
# Labelling template >> <*> 0 <*> 1615 <*> 8 11 0 logger
# Labelling template >> [13307] 0 13307 30360 962 38 4833 0 httpd
# Labelling template >> [ 4805] 198 4805 332243 33787 575 4267 0 f5-rest-node
# Labelling template >> [18743] 0 18743 16514 6016 31 2162 0 bigd
# Labelling template >> [18742] 0 18742 16437 6076 32 2078 0 bigd
# Labelling template >> [18741] 0 18741 16362 5988 32 2107 0 bigd
# Labelling template >> [18255] 0 18255 3270 642 10 237 0 rrdshim
# Labelling template >> [17806] 0 17806 3695696 41287 128 0 -500 tmm.0
# Labelling template >> [17804] 25 17804 22491 284 39 13418 0 named
# Labelling template >> [17671] 91 17671 151064 58693 203 25646 0 java
# Labelling template >> [14133] 0 14133 1957 166 8 387 0 ntlmconnpool
# Labelling template >> [13259] 0 13259 26096 785 55 5288 0 bwafconfd
# Labelling template >> [13238] 0 13238 895 193 5 26 0 bigd.start
# Labelling template >> [12901] 0 12901 8820 3963 20 2721 0 vxland
# Labelling template >> [12898] 0 12898 18965 223 42 151 0 su
# Labelling template >> [12895] 0 12895 1082 122 8 27 -500 tmm.start
# Labelling template >> [12893] 0 12893 13880 3992 24 2398 0 tmipsecd
# Labelling template >> [12890] 0 12890 33196 1469 67 5317 0 pccd
# Labelling template >> [12887] 0 12887 42652 2036 81 4386 0 mgmt_acld
# Labelling template >> [12885] 0 12885 8417 4005 20 2445 0 iprepd
# Labelling template >> [10450] 0 10450 13319 280 29 173 0 ntpd
# Labelling template >> [ 9938] 0 9938 10119 747 21 339 0 tamd
# Labelling template >> [ <*> 0 <*> 532 <*> 4 <*> 0 runsv
# Labelling template >> [ 9703] 0 9703 2764 76 10 42 0 rsync
# Labelling template >> [ 9352] 0 9352 39164 1333 71 5509 0 sflow_agent
# Labelling template >> [ 8949] 0 8949 12480 2218 23 3918 0 statsd
# Labelling template >> [ 8948] 0 8948 38460 14862 74 321 0 merged
# Labelling template >> [ 8947] 0 8947 15358 991 27 682 0 tmrouted
# Labelling template >> [ 8941] 0 8941 32760 2078 62 4457 0 logstatd
# Labelling template >> [ 8548] 0 8548 19921 3637 41 4133 0 cbrd
# Labelling template >> [ 8544] 0 8544 18171 981 31 667 0 zxfrd
# Labelling template >> [ 7757] 0 7757 21065 20774 45 0 0 sod
# Labelling template >> [ 7756] 0 7756 7629 3838 18 1825 0 lind
# Labelling template >> [ 7755] 0 7755 35132 3922 43 2794 0 keymgmtd
# Labelling template >> [ 7562] 0 7562 9733 3880 22 2671 0 devmgmtd
# Labelling template >> [ 7233] 0 7233 11425 7184 25 1783 0 csyncd
# Labelling template >> [ 7232] 0 7232 13611 4047 25 2281 0 eventd
# Labelling template >> [ 7226] 0 7226 70587 21138 174 11194 0 mcpd
# Labelling template >> [ 7225] 0 7225 8366 3966 20 2483 0 evrouted
# Labelling template >> [ 7222] 0 7222 9919 1188 18 1227 0 alertd
# Labelling template >> [ 6867] 0 6867 7489 1000 13 270 0 wccpd
# Labelling template >> [ 6857] 0 6857 26083 883 53 5887 0 dynconfd
# Labelling template >> [ 6444] 0 6444 174789 111791 314 22003 0 java
# Labelling template >> [ 6442] 0 6442 34931 2257 63 4995 0 snmpd
# Labelling template >> [ 6437] 0 6437 34974 4101 54 4676 0 scriptd
# Labelling template >> [ 5978] 0 5978 11082 4234 24 2365 0 icr_eventd
# Labelling template >> [ 5537] 0 5537 25088 1649 20 181 0 errdefsd
# Labelling template >> [ 5536] 0 5536 7656 3518 18 2293 0 syscalld
# Labelling template >> [ 5268] 0 5268 8412 8404 20 0 0 lacpd
# Labelling template >> [ 5000] 0 5000 569 59 5 11 0 runsvdir
# Labelling template >> [ 4995] 0 4995 41806 5137 46 3046 0 chmand
# Labelling template >> [ 4556] 0 4556 31356 286 62 265 -1000 sshd
# Labelling template >> [ 4378] 0 4378 27516 169 9 29 0 agetty
# Labelling template >> [ 4376] 0 4376 27516 176 10 31 0 agetty
# Labelling template >> [ 3924] 0 3924 19870 4153 26 2399 0 promptstatusd
# Labelling template >> [ 3923] 0 3923 31571 237 19 142 0 crond
# Labelling template >> [ 3918] 0 3918 5523 216 17 40 0 systemd-logind
# Labelling template >> [ 2791] 0 2791 168412 1319 72 1780 0 syslog-ng
# Labelling template >> [ 1868] 0 1868 2679 21 10 38 0 increase_entrop
# Labelling template >> [ 1827] 0 1827 1090 99 7 33 0 acpid
# Labelling template >> [ 1818] 0 1818 1749 55 9 15 0 mdadm
# Labelling template >> [ 1813] 0 1813 5412 234 15 37 0 irqbalance
# Labelling template >> [ 1812] 0 1812 22927 22634 49 0 0 overdog
# Labelling template >> [ 1794] 81 1794 14969 231 28 79 -900 dbus-daemon
# Labelling template >> [ 1763] 0 1763 13922 221 27 87 -1000 auditd
# Labelling template >> [ 1735] 0 1735 1083 103 7 12 0 jitterentropy-r
# Labelling template >> [ 555] 0 555 11566 224 25 568 -1000 systemd-udevd
# Labelling template >> [ 545] 0 545 50862 171 31 446 0 lvmetad
# Labelling template >> [ 518] 0 518 62175 341 40 83 0 vmtoolsd
# Labelling template >> [ 516] 0 516 8288 239 22 61 0 systemd-journal
# Labelling template >> [ pid ] uid tgid total_vm rss nr_ptes swapents oom_score_adj name
# Labelling template >> 85814 pages reserved
# Labelling template >> 0 pages HighMem/MovableOnly
# Labelling template >> 4194174 pages RAM
# Labelling template >> Total swap = 1023996kB
# Labelling template >> Free swap = 1752kB
# Labelling template >> Swap cache stats: add 83004122, delete <*> find 121895098/131013443
# Labelling template >> 17962 pages in swap cache
# Labelling template >> 90781 total pagecache pages
# Labelling template >> Node 0 hugepages_total=6896 hugepages_free=17 hugepages_surp=0 hugepages_size=2048kB
# Labelling template >> Node 0 hugepages_total=0 hugepages_free=0 hugepages_surp=0 hugepages_size=1048576kB
# Labelling template >> Node 0 Normal: <*> (UEM) <*> (UEM) 256*16kB (UEM) <*> (UEM) 53*64kB (UEM) 21*128kB (UEM) 2*256kB (UM) 0*512kB 0*1024kB 0*2048kB 0*4096kB = <*>
# Labelling template >> Node 0 DMA32: 159*4kB (UEM) 108*8kB (UE) 81*16kB (UEM) 62*32kB (UEM) 16*64kB (UEM) 7*128kB (E) 3*256kB (UEM) 4*512kB (E) 0*1024kB 3*2048kB (UEM) 10*4096kB (EM) = 56620kB
# Labelling template >> Node 0 DMA: 1*4kB (U) 0*8kB 0*16kB 1*32kB (U) 2*64kB (U) 1*128kB (U) 1*256kB (U) 0*512kB 1*1024kB (U) 1*2048kB (M) 3*4096kB (M) = 15908kB
# Labelling template >> lowmem_reserve[]: 0 0 0 0
# Labelling template >> Node 0 Normal <*> min:19636kB low:24544kB high:29452kB active_anon:1496712kB <*> active_file:0kB inactive_file:0kB unevictable:251336kB isolated(anon):0kB isolated(file):0kB present:13631488kB managed:13367456kB mlocked:251336kB dirty:128kB writeback:0kB mapped:204528kB shmem:118616kB slab_reclaimable:44576kB slab_unreclaimable:131496kB kernel_stack:9504kB pagetables:20620kB unstable:0kB bounce:0kB <*> <*> free_cma:0kB writeback_tmp:0kB <*> all_unreclaimable? <*>
# Labelling template >> lowmem_reserve[]: 0 0 13054 13054
# Labelling template >> Node 0 DMA32 free:56596kB min:4480kB low:5600kB high:6720kB active_anon:8192kB inactive_anon:2328kB active_file:0kB inactive_file:0kB unevictable:19340kB isolated(anon):0kB isolated(file):0kB present:3129216kB managed:3050076kB mlocked:19340kB dirty:4kB writeback:0kB <*> shmem:72kB slab_reclaimable:5016kB slab_unreclaimable:4400kB kernel_stack:304kB pagetables:272kB unstable:0kB bounce:0kB <*> <*> free_cma:0kB writeback_tmp:0kB pages_scanned:298 all_unreclaimable? yes
# Labelling template >> lowmem_reserve[]: 0 2977 16031 16031
# Labelling template >> Node 0 DMA free:15908kB min:20kB low:24kB high:28kB active_anon:0kB inactive_anon:0kB active_file:0kB inactive_file:0kB unevictable:0kB isolated(anon):0kB isolated(file):0kB present:15992kB managed:15908kB mlocked:0kB dirty:0kB writeback:0kB mapped:0kB shmem:0kB slab_reclaimable:0kB slab_unreclaimable:0kB kernel_stack:0kB pagetables:0kB unstable:0kB bounce:0kB free_pcp:0kB local_pcp:0kB free_cma:0kB writeback_tmp:0kB pages_scanned:0 all_unreclaimable? yes
# Labelling template >> active_anon:376226 inactive_anon:38742 isolated_anon:0
# Labelling template >> Mem-Info:
# Labelling template >> [<ffffffff816c6768>] page_fault+0x28/0x30
# Labelling template >> [<ffffffff816ca855>] do_page_fault+0x35/0x90
# Labelling template >> [<ffffffff816ca506>] __do_page_fault+0x176/0x490
# Labelling template >> [<ffffffff811b63f2>] handle_mm_fault+0xc2/0x150
# Labelling template >> [<ffffffff812544c9>] ? ep_scan_ready_list.isra.7+0x1b9/0x1f0
# ...
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:05f3c861: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:4242f3b0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:26f6c91e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2f77beb6: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b4094eb9: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8ddbfe64: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dd7924b9: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ef676edd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d2a46f85: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:19c4620f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:63292105: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c2dd8724: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:95f660c3: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:895a8873: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:4e7e0ffd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:4958b8c7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d3789321: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:df03c280: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b6d65ed0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:02d36349: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:46b8267e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b325ed1c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:79e261d9: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d13a794f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5647c34a: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e9718aac: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1df596c6: Logging Agent
# Labelling template >> EVENT MONITORUP <*> 0 : Monitor <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:4dc8121f: Logging Agent
# Labelling template >> EVENT MONITORDOWN <*> 0 : Monitor <*>
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:57c8e2a2: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:450bc028: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3c7f7f9f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7ce371e7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:635f5bd3: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a2522ed5: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:bfccd5d7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:be6cb56f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5d220b67: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:065624bb: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7ef754a3: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:756902e8: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:cc804e4f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b3922f2a: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2eca11bf: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:28e76e07: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a86352e8: Logging Agent
# Labelling template >> 22402,22408, RestServer, INFO,ScheduledTasks running late
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:66c2e474: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fd7baf03: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:be11b2e1: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:353d6f7f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:6c31408c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:68e8813e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:109bac4d: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c98a39a7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:666da15d: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:18f24aa9: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3fb05d37: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:682ce9ec: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f225d747: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:97c60235: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7c16d583: Logging Agent
# Labelling template >> 16007,16009, RestServer, INFO,ScheduledTasks running late
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9812f8f9: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0293e7f0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:090252bc: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:676b2320: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:6de7e928: Logging Agent
# Labelling template >> Suppressed 173 messages from /system.slice/sshd.service
# Labelling template >> Suppressed 575 messages from /system.slice/sshd.service
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0663781e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:df681d26: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ddcb58ef: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:cfc2e98f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8c758f62: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:eaf7d54c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c64c6286: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:871a9452: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:78ddfbbb: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:04034a5c: Logging Agent
# Labelling template >> Suppressed 497 messages from /system.slice/sshd.service
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:11746715: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0a9b75b4: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7a8600d5: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5aa332e6: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:70c04a7c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c5750a8e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:53c20192: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:35af56fd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:858b0409: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:06a8bd32: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9441d4ec: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:77b8c4df: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fba6ad65: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1501a1e1: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8b1260ab: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d622e721: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:812da368: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f3d5b06d: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5cab3118: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0f96a469: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0c5fd9d3: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9d1879f4: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:16bd4d41: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:aff88cfd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:80ee2f0c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fbcce779: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e1a55537: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:d01eb6c2: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3399d041: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dc81983e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:079a8000: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9f733089: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f1e566bf: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e52c5a6f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e1fe6a30: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c830353e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:062adc07: Logging Agent
# Labelling template >> pam_tacplus: pam_tacplus: user svcnetops successfully authenticated
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:f4da61ac: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:912df7d7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a15b9feb: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:91b0cfae: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:610c3bbe: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7e289afd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:cb1e08f8: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e5a1a1ae: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7d6ac032: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e336f586: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:759078de: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e77eb67e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7f29073b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9333abb1: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:999eccb1: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:42a56d77: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:7f29df65: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5d626fba: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c11d5723: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:bf947426: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:967b582c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:12d1d2f4: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:3942642b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:a997cd4b: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ec7939b7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:21733079: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9097f220: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:1063440f: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:9d2c537c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:c614bd0e: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ab26a2f1: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fdfecd90: Logging Agent
# Labelling template >> Suppressed 159 messages from /system.slice/sshd.service
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:829d8032: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e7e4452b: Logging Agent
# Labelling template >> 01070808:5: Monitor /Common/icmp instance <*> has been enabled.
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:2bab05c0: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:b96d42e5: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:99090582: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:ee07ea72: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:35baa7b4: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:35cfff8c: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fecc2830: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:0f452ab5: Logging Agent
# Labelling template >> 19216,19221, RestServer, INFO,ScheduledTasks running late
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:e8b06b48: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:8436fab7: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:dc90b059: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:fdc1bbcd: Logging Agent
# Labelling template >> 01490142:5: /Common/wmgate_accesspolicy:Common:5d805109: Logging Agent
# Labelling template >> 2-PPE-11 : default SNMP TRAP_SENT 0 1709219845731293 : netScalerConfigChange (nsUserName = "svcnetops", configurationCmd = "add ns ip <*> <*> -type VIP ...", authorizationStatus = authorized, commandExecutionStatus = successful, nsClientIPAddr = <*>, nsPartitionName = default)
# Total templates 2036
# Processed records 6415592

# %%
# Save the template data to a CSV file
template_df = pd.DataFrame(template_data, columns=['Label', 'Template'])
template_df.to_csv('../result/template.csv', index=False)

# Save the structured data to a CSV file

st_columns = ['LineId', 'Content', 'EventId', 'EventTemplate', 'ParameterList', 'Label']
# st_columns = ['LineId', 'Content', 'EventId', 'EventTemplate', 'ParameterList', 'Label']
structured_df = pd.DataFrame(structured_data, columns=st_columns)
structured_df.to_csv('../result/structured.csv', index=False)

st_columns = ['Content', 'Label']
structured_df = pd.DataFrame(structured_data, columns=structured_df.columns)
structured_df.to_csv('../../roberta/data/data.csv', index=False)
